# %% [markdown]
# # Digital Aristotle

# %% [markdown]
# ###### Modules

# %%
# %matplotlib inline

# %%
# %load deserialize.py
import json
from matplotlib.pylab import *
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import random
import time
from IPython import display
from itertools import chain
import nltk
from IPython.display import HTML

# %% [markdown]
# ###### Data Components

# %%
class Serializable(object):
    @classmethod
    def fromJsonFile(cls,fname):
        f = open("Math6")
        document = json.loads(f.read().encode('utf8'))
        return cls.fromJsonObj(document)

    @classmethod
    def fromJsonObj(cls,obj):
        pass
    
    def toJSONObj(self):
        pass
    
    def __str__(self):
        return (json.dumps(self.toJSONObj(), indent=2))

class Book(Serializable):
    #                 str  [Chapter] str         str
    def __init__(self,name,chapters,publish_date,isbn):
        self.name = name
        self.chapters = chapters
        self.publish_date = publish_date
        self.isbn = isbn

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],[Chapter.fromJsonObj(obj) for obj in dictionary['chapters']],dictionary['publish_date'],dictionary['isbn'])

    def toJSONObj(self):
        return {'name' : self.name, 'chapters' : [obj.toJSONObj() for obj in self.chapters], 'publish_date': self.publish_date, 'isbn': self.isbn}
    
class Chapter(Serializable):
    #                 str  [Sub_Chapter] [Subject] 
    def __init__(self,name,subchapters,subjects,page):
        self.name = name
        self.subchapters = subchapters
        self.subjects = subjects
        self.page = page

    def toJSONObj(self):
        return {'name' : self.name, 'subchapters' : [x.toJSONObj() for x in self.subchapters], 'subjects': self.subjects, 'page':self.page}
    
    
    
    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],[SubChapter.fromJsonObj(obj) for obj in dictionary['subchapters']],dictionary['subjects'],dictionary['page'])

class SubChapter(Serializable):
    #                  str [Paragraph] [Subject]
    def __init__(self,name,text,subjects, page):
        self.name = name
        self.text = text
        self.subjects = subjects
        self.page = page

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],dictionary['text'],dictionary['subjects'],dictionary['page'])

    def toJSONObj(self):
        return {'name' : self.name, 'text' : self.text, 'subjects': self.subjects, 'page': self.page}
    
   
class Subject(object):
    def __init__(self,text):
        self.text = text

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['text'])

# %% [markdown]
# ###### Data Creation

# %%
f = open("LinedMath.json")
book = Book('A First Book in Algebra',[],"","")
document = json.loads(f.read().encode('utf8'))
chapter = None
subchapter = None
for (page_num, page) in enumerate(document):
    page_num += 1
    for line in page:
        if line[u'font'] == 5: # chapter
            chapter = Chapter(line[u'data'], [], [line[u'data']], page_num)
            book.chapters.append(chapter)
            subchapter = None

        elif line[u'font'] == 3: # Subchapter
            subchapter = SubChapter(line[u'data'], '', [line[u'data']], page_num)
            if chapter is None:
                chapter = Chapter('No Name Chapter', [], [], page_num)
            chapter.subchapters.append(subchapter)
            chapter.subjects.append(line[u'data'])
        
        elif subchapter is not None:
            subchapter.text += u'\n' + line[u'data']
        
        else:
            subchapter = SubChapter("No Name", line[u'data'], [], page_num)
            if chapter is None:
                chapter = Chapter('No Name Chapter', [], [], page_num)
            chapter.subchapters.append(subchapter)

fout = open("newMathOut.json",'w')
string = json.dumps(book.toJSONObj())
fout.write(string)

# %% [raw]
# f = open('newMathOut.json')
# book = Book.fromJsonObj(json.loads(f.read()))
# # print book
# for chapter in book.chapters:
# #     print chapter
#     print type(chapter.subchapters)

# %% [markdown]
# ###### Search Data (Functions)

# %%
def levenshtein(source, target):
    if len(source) < len(target):
        return levenshtein(target, source)
 
    if len(target) == 0:
        return len(source)
    source = np.array(tuple(source))
    target = np.array(tuple(target))
 
    previous_row = np.arange(target.size + 1)
    for s in source:
        # Insertion 
        current_row = previous_row + (0.1)
 
        # Substitution or matching:
        current_row[1:] = np.minimum(current_row[1:],np.add(previous_row[:-1], (target != s) * (3)))
 
        # Deletion 
        current_row[1:] = np.minimum(
                current_row[1:],
                current_row[0:-1] + (1))
        previous_row = current_row
 
    return previous_row[-1]
levenshtein = np.vectorize(levenshtein)

# %%
def minimumChapter(xs):
    smallest = float("inf")
    smallestChapter = None
    for (value, chapter) in xs:
        if value < smallest:
            smallest = value
            smallestChapter = chapter
    return smallestChapter

# %%
numberOfTimesRan = 0
filtered_words_global = []
def bestChapter(input_string, chapters):
    def countWordsInSubChapter(subchapter):
        global numberOfTimesRan, filtered_words_global
        numberOfTimesRan += 1
        accum = 0
        text = subchapter.text
        words = text.split()
        filtered_words = [w.lower() for w in words if not w.lower() in stopWords and not isInt(w) and w.isalpha() and len(w) > 2]
        accum -= len([w for w in filtered_words if w == input_string])
        filtered_words_global += filtered_words
        for word in filtered_words:
            comp = levenshteinDistance(input_string,word)
            accum += float(comp) / len(words)
        return accum
    
    countWordsInSubChapter = memoize(countWordsInSubChapter)
    
    def chapterPlusIndex(chapter):
        index = levenshteinDistance(input_string, chapter.name)
        if type(chapter) is SubChapter:
            index += countWordsInSubChapter(chapter)
            print '\t', chapter.name, index
        elif type(chapter) is Chapter:
            accum = 0
            for subchapter in chapter.subchapters:
                accum += countWordsInSubChapter(subchapter)
            accum = accum/len(chapter.subchapters)
            index += accum
            print chapter.name, index
            
        return (float(index), chapter)
    xs = map(chapterPlusIndex, chapters)
#     print map(lambda x: (x[0], x[1].name), xs)
    return minimumChapter(xs)

# %%
def memoize(f):
    memory = dict()
    def memoizedFunction(x):
        if x in memory:
            return memory[x]
        else:
            memory[x] = f(x)
            return memory[x]
    return memoizedFunction

# %%
def getChapter(input_string):
    return bestChapter(input_string, list(chain(*[c.subchapters for c in book.chapters])) + book.chapters)

# %%
def levenshteinDistance(str1,str2):
    str1, str2 = unicode(str1), unicode(str2)
    return levenshtein(str1.lower().rstrip('.'),str2.lower().rstrip('.'))

# %%
def isInt(string):
    string = [x for x in string if x in '0123456789']
    return len(string) > 0

# %% [markdown]
# ###### Search Data

# %%
stopwords = """
a about above after again agains all am an and any are aren't as at be because been before being below between both but by can't cannot could couldn't did didn't do does doesn't doing don't down during each few for from further had hadn't has hasn't have haven't having he he'd he'll he's her here here's hers herself him himself his how how's i i'd i'll i'm i've if in into is isn't it it's its itself let's me more most mustn't my myself no nor not of off on once only or other ought our ours ourselves out over own same shan't she she'd she'll she's should shouldn't so some such than that that's the their theirs them themselves then there there's these they they'd they'll they're they've this those through to too under until up very was wasn't we we'd we'll we're we've were weren't what what's when when's where where's which while who who's whom why why's with won't would wouldn't you you'd you'll you're you've your yours yourself yourselves first second twice third fourth - + 
one two three four five six seven eight nine ten john many times much will can miles years cent men hours exercise man must 
"""
stopWords = stopwords.split()

# %%
input_string = u'something'
filtered_words_global = []
chapter = getChapter(input_string)
print chapter.name
print 
print chapter.page
# Out:
# 	No Name 6.58364875095
# MODES OF REPRESENTING THE OPERATIONS. 6.04082926829
# 	ALGEBRAIC EXPRESSIONS. 8.96243654822
# ADDITION. 6.23803418803
# SUBTRACTION. 6.42483320979
# MULTIPLICATION. 6.56480706648
# DIVISION. 6.28496319664
# FACTORING. 6.00117173197
# 	GREATEST COMMON FACTOR. 8.53808290155
# LEAST COMMON MULTIPLE. 5.91073211314
# 	No Name 7.81851851852
# 	REDUCTION OF FRACTIONS. 7.32263948498
# OPERATIONS UPON FRACTIONS. 6.43163008276
# 	COMPLEX FRACTIONS. 4.63300835655
# No Name 6.49183186052
# SIMULTANEOUS EQUATIONS. 5.20138465799
# ALGEBRAIC NOTATION. 7.46230485582
# OPERATIONS. 5.15315941523
# FACTORS AND MULTIPLES. 7.18332891556
# FRACTIONS. 7.5014491107
# EQUATIONS 7.29660825926
# COMPLEX FRACTIONS.
#
# 96

# %%
numberOfTimesRan
# Out:
# 16

# %%
words = []
for chapter in book.chapters:
    for subchapter in chapter.subchapters:
        splited = subchapter.text.split()
        words += splited
print words
# Out:
# [u'1.', u'Algebra', u'is', u'so', u'much', u'like', u'arithmetic', u'that', u'all', u'that', u'you', u'know', u'about', u'addition,', u'subtraction,', u'multiplication,', u'and', u'division,', u'the', u'signs', u'that', u'you', u'have', u'been', u'using', u'and', u'the', u'ways', u'of', u'working', u'out', u'problems,', u'will', u'be', u'very', u'useful', u'to', u'you', u'in', u'this', u'study.', u'There', u'are', u'two', u'things', u'the', u'introduction', u'of', u'which', u'really', u'makes', u'all', u'the', u'difference', u'between', u'arithmetic', u'and', u'algebra.', u'One', u'of', u'these', u'is', u'the', u'use', u'of', u'letters', u'to', u'represent', u'numbers,', u'and', u'you', u'will', u'see', u'in', u'the', u'following', u'exercises', u'that', u'this', u'change', u'makes', u'the', u'solution', u'of', u'problems', u'much', u'easier.', u'Exercise', u'I.', u'Illustrative', u'Example.', u'The', u'sum', u'of', u'two', u'numbers', u'is', u'60,', u'and', u'the', u'greater', u'is', u'four', u'times', u'the', u'less.', u'What', u'are', u'the', u'numbers?', u'Solution.', u'Letx=', u'the', u'less', u'number;', u'then4x=', u'the', u'greater', u'number,', u'and4x', u'+', u'x=60,', u'or5x=60;', u'thereforex=12,', u'and4x=48.', u'The', u'numbers', u'are', u'12', u'and', u'48.', u'1.', u'The', u'greater', u'of', u'two', u'numbers', u'is', u'twice', u'the', u'less,', u'and', u'the', u'sum', u'of', u'the', u'numbers', u'is', u'129.', u'What', u'are', u'the', u'numbers?', u'2.', u'A', u'man', u'bought', u'a', u'horse', u'and', u'carriage', u'for', u'$500,', u'paying', u'three', u'times', u'as', u'much', u'for', u'the', u'carriage', u'as', u'for', u'the', u'horse.', u'How', u'much', u'did', u'each', u'cost?', u'3.', u'Two', u'brothers,', u'counting', u'their', u'money,', u'found', u'that', u'together', u'they', u'had', u'$186,', u'and', u'that', u'John', u'had', u'five', u'times', u'as', u'much', u'as', u'Charles.', u'How', u'much', u'had', u'each?', u'4.', u'Divide', u'the', u'number', u'64', u'into', u'two', u'parts', u'so', u'that', u'one', u'part', u'shall', u'be', u'seven', u'times', u'the', u'other.', u'5.', u'A', u'man', u'walked', u'24', u'miles', u'in', u'a', u'day.', u'If', u'he', u'walked', u'twice', u'as', u'far', u'in', u'the', u'forenoon', u'as', u'in', u'the', u'afternoon,', u'how', u'far', u'did', u'he', u'walk', u'in', u'the', u'afternoon?', u'7', u'6.', u'For', u'72', u'cents', u'Martha', u'bought', u'some', u'needles', u'and', u'thread,', u'paying', u'eight', u'times', u'as', u'much', u'for', u'the', u'thread', u'as', u'for', u'the', u'needles.', u'How', u'much', u'did', u'she', u'pay', u'for', u'each?', u'7.', u'In', u'a', u'school', u'there', u'are', u'672', u'pupils.', u'If', u'there', u'are', u'twice', u'as', u'many', u'boys', u'as', u'girls,', u'how', u'many', u'boys', u'are', u'there?', u'Illustrative', u'Example.', u'If', u'the', u'difference', u'between', u'two', u'numbers', u'is', u'48,', u'and', u'one', u'number', u'is', u'five', u'times', u'the', u'other,', u'what', u'are', u'the', u'numbers?', u'Solution.', u'Letx=', u'the', u'less', u'number;', u'then5x=', u'the', u'greater', u'number,', u'and5x', u'-', u'x=48,', u'or4x=48;', u'thereforex=12,', u'and5x=60.', u'The', u'numbers', u'are', u'12', u'and', u'60.', u'8.', u'Find', u'two', u'numbers', u'such', u'that', u'their', u'difference', u'is', u'250', u'and', u'one', u'is', u'eleven', u'times', u'the', u'other.', u'9.', u'James', u'gathered', u'12', u'quarts', u'of', u'nuts', u'more', u'than', u'Henry', u'gathered.', u'How', u'many', u'did', u'each', u'gather', u'if', u'James', u'gathered', u'three', u'times', u'as', u'many', u'as', u'Henry?', u'10.', u'A', u'house', u'cost', u'$2880', u'more', u'than', u'a', u'lot', u'of', u'land,', u'and', u'five', u'times', u'the', u'cost', u'of', u'the', u'lot', u'equals', u'the', u'cost', u'of', u'the', u'house.', u'What', u'was', u'the', u'cost', u'of', u'each?', u'11.', u'Mr.', u'A.', u'is', u'48', u'years', u'olde ...

# %%
text = nltk.Text(list(chain(*map(nltk.word_tokenize,filtered_words_global))))

# %%
# nltk.FreqDist(text).most_common(50) 
# len(text)
text.count('fun')
# Out:
# 0

# %% [markdown]
# ###### Test

# %%
book.chapters + list(chain(*[c.subchapters for c in book.chapters]))
# Out:
# [<__main__.Chapter at 0x10d5b0350>,
#  <__main__.Chapter at 0x10d5b0310>,
#  <__main__.Chapter at 0x10d5b0490>,
#  <__main__.Chapter at 0x10da41fd0>,
#  <__main__.Chapter at 0x10da41e50>,
#  <__main__.SubChapter at 0x10e119090>,
#  <__main__.SubChapter at 0x10e119050>,
#  <__main__.SubChapter at 0x10e1190d0>,
#  <__main__.SubChapter at 0x10d5b0390>,
#  <__main__.SubChapter at 0x10d5b03d0>,
#  <__main__.SubChapter at 0x10d5b0410>,
#  <__main__.SubChapter at 0x10d5b0450>,
#  <__main__.SubChapter at 0x10d5b04d0>,
#  <__main__.SubChapter at 0x10d5b0510>,
#  <__main__.SubChapter at 0x10d5b0550>,
#  <__main__.SubChapter at 0x10da41f90>,
#  <__main__.SubChapter at 0x10da41f10>,
#  <__main__.SubChapter at 0x10da41e90>,
#  <__main__.SubChapter at 0x10ce292d0>,
#  <__main__.SubChapter at 0x10ce18150>,
#  <__main__.SubChapter at 0x10ce18190>]

# %%
print levenshtein("ALGEBRAIC NOTATION.".lower(), "facor".lower())
# Out:
# 3.6

# %%
stopWords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'agains',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'same',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'first',
#  'second',
#  'twice',
#  'third',
#  'fourth',
#  '-',
#  '+',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'john',
#  'many',
#  'times',
#  'much',
#  'will',
#  'can',
#  'miles',
#  'years',
#  'cent',
#  'men',
#  'hours',
#  'exercise',
#  'man',
#  'must']

# %%
unicode.isalpha(u'a')
# Out:
# True

# %%
for (i,elem) in enumerate(stopWords):
    print i, elem
# Out:
# 0 a
# 1 about
# 2 above
# 3 after
# 4 again
# 5 agains
# 6 all
# 7 am
# 8 an
# 9 and
# 10 any
# 11 are
# 12 aren't
# 13 as
# 14 at
# 15 be
# 16 because
# 17 been
# 18 before
# 19 being
# 20 below
# 21 between
# 22 both
# 23 but
# 24 by
# 25 can't
# 26 cannot
# 27 could
# 28 couldn't
# 29 did
# 30 didn't
# 31 do
# 32 does
# 33 doesn't
# 34 doing
# 35 don't
# 36 down
# 37 during
# 38 each
# 39 few
# 40 for
# 41 from
# 42 further
# 43 had
# 44 hadn't
# 45 has
# 46 hasn't
# 47 have
# 48 haven't
# 49 having
# 50 he
# 51 he'd
# 52 he'll
# 53 he's
# 54 her
# 55 here
# 56 here's
# 57 hers
# 58 herself
# 59 him
# 60 himself
# 61 his
# 62 how
# 63 how's
# 64 i
# 65 i'd
# 66 i'll
# 67 i'm
# 68 i've
# 69 if
# 70 in
# 71 into
# 72 is
# 73 isn't
# 74 it
# 75 it's
# 76 its
# 77 itself
# 78 let's
# 79 me
# 80 more
# 81 most
# 82 mustn't
# 83 my
# 84 myself
# 85 no
# 86 nor
# 87 not
# 88 of
# 89 off
# 90 on
# 91 once
# 92 only
# 93 or
# 94 other
# 95 ought
# 96 our
# 97 ours
# 98 ourselves
# 99 out
# 100 over
# 101 own
# 102 same
# 103 shan't
# 104 she
# 105 she'd
# 106 she'll
# 107 she's
# 108 should
# 109 shouldn't
# 110 so
# 111 some
# 112 such
# 113 than
# 114 that
# 115 that's
# 116 the
# 117 their
# 118 theirs
# 119 them
# 120 themselves
# 121 then
# 122 there
# 123 there's
# 124 these
# 125 they
# 126 they'd
# 127 they'll
# 128 they're
# 129 they've
# 130 this
# 131 those
# 132 through
# 133 to
# 134 too
# 135 under
# 136 until
# 137 up
# 138 very
# 139 was
# 140 wasn't
# 141 we
# 142 we'd
# 143 we'll
# 144 we're
# 145 we've
# 146 were
# 147 weren't
# 148 what
# 149 what's
# 150 when
# 151 when's
# 152 where
# 153 where's
# 154 which
# 155 while
# 156 who
# 157 who's
# 158 whom
# 159 why
# 160 why's
# 161 with
# 162 won't
# 163 would
# 164 wouldn't
# 165 you
# 166 you'd
# 167 you'll
# 168 you're
# 169 you've
# 170 your
# 171 yours
# 172 yourself
# 173 yourselves
# 174 first
# 175 second
# 176 twice
# 177 third
# 178 fourth
# 179 -
# 180 +
# 181 one
# 182 two
# 183 three
# 184 four
# 185 five
# 186 six
# 187 seven
# 188 eight
# 189 nine
# 190 ten
# 191 john
# 192 many
# 193 times
# 194 much
# 195 will
# 196 can
# 197 miles
# 198 years
# 199 cent
# 200 men
# 201 hours
# 202 exercise
# 203 man
# 204 must
