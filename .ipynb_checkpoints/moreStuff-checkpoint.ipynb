# %% [markdown]
# # Digital Aristotle

# %% [markdown]
# ###### Modules

# %%
# %matplotlib inline

# %%
# %load deserialize.py
import json
from matplotlib.pylab import *
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import random
import time
from IPython import display
from itertools import chain
import nltk

# %% [markdown]
# ###### Data Components

# %%
class Serializable(object):
    @classmethod
    def fromJsonFile(cls,fname):
        f = open("Math6")
        document = json.loads(f.read().encode('utf8'))
        return cls.fromJsonObj(document)

    @classmethod
    def fromJsonObj(cls,obj):
        pass
    
    def toJSONObj(self):
        pass

class Book(Serializable):
    #                 str  [Chapter] str         str
    def __init__(self,name,chapters,publish_date,isbn):
        self.name = name
        self.chapters = chapters
        self.publish_date = publish_date
        self.isbn = isbn

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],[Chapter.fromJsonObj(obj) for obj in dictionary['chapters']],dictionary['publish_date'],dictionary['isbn'])

    def toJSONObj(self):
        return {'name' : self.name, 'chapters' : [obj.toJSONObj() for obj in self.chapters], 'publish_date': self.publish_date, 'isbn': self.isbn}
    
class Chapter(Serializable):
    #                 str  [Sub_Chapter] [Subject] 
    def __init__(self,name,subchapters,subjects):
        self.name = name
        self.subchapters = subchapters
        self.subjects = subjects

    def toJSONObj(self):
        return {'name' : self.name, 'subchapters' : [x.toJSONObj() for x in self.subchapters], 'subjects': self.subjects}
    
    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],[SubChapter.fromJsonObj(obj) for obj in dictionary['subchapters']],dictionary['subjects'])

class SubChapter(Serializable):
    #                  str [Paragraph] [Subject]
    def __init__(self,name,text,subjects):
        self.name = name
        self.text = text
        self.subjects = subjects

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['name'],dictionary['text'],dictionary['subjects'])

    def toJSONObj(self):
        return {'name' : self.name, 'text' : self.text, 'subjects': self.subjects}
   
class Subject(object):
    def __init__(self,text):
        self.text = text

    @classmethod
    def fromJsonObj(cls,dictionary):
        return cls(dictionary['text'])

# %% [markdown]
# ###### Data Creation

# %%
f = open("LinedMath.json")
book = Book('A First Book in Algebra',[],"","")
document = json.loads(f.read().encode('utf8'))
chapter = None
subchapter = None
for page in document:
    for line in page:
        if line[u'font'] == 5: # chapter
            chapter = Chapter(line[u'data'], [], [line[u'data']])
            book.chapters.append(chapter)
            subchapter = None

        elif line[u'font'] == 3: # Subchapter
            subchapter = SubChapter(line[u'data'], '', [line[u'data']])
            if chapter is None:
                chapter = Chapter('No Name Chapter', [], [])
            chapter.subchapters.append(subchapter)
            chapter.subjects.append(line[u'data'])
        
        elif subchapter is not None:
            subchapter.text += u'\n' + line[u'data']
        
        else:
            subchapter = SubChapter("No Name", line[u'data'], [])
            if chapter is None:
                chapter = Chapter('No Name Chapter', [], [])
            chapter.subchapters.append(subchapter)

fout = open("newMathOut.json",'w')
string = json.dumps(book.toJSONObj())
fout.write(string)

# %% [raw]
# f = open('newMathOut.json')
# book = Book.fromJsonObj(json.loads(f.read()))
# # print book
# for chapter in book.chapters:
# #     print chapter
#     print type(chapter.subchapters)

# %% [markdown]
# ###### Search Data (Functions)

# %%
def levenshtein(source, target):
    if len(source) < len(target):
        return levenshtein(target, source)
 
    if len(target) == 0:
        return len(source)
    source = np.array(tuple(source))
    target = np.array(tuple(target))
 
    previous_row = np.arange(target.size + 1)
    for s in source:
        # Insertion 
        current_row = previous_row + (0.1)
 
        # Substitution or matching:
        current_row[1:] = np.minimum(current_row[1:],np.add(previous_row[:-1], (target != s) * (3)))
 
        # Deletion 
        current_row[1:] = np.minimum(
                current_row[1:],
                current_row[0:-1] + (1))
        previous_row = current_row
 
    return previous_row[-1]
levenshtein = np.vectorize(levenshtein)

# %%
def minimumChapter(xs):
    smallest = float("inf")
    smallestChapter = None
    for (value, chapter) in xs:
        if value < smallest:
            smallest = value
            smallestChapter = chapter
    return smallestChapter

# %%
numberOfTimesRan = 0
def bestChapter(input_string, chapters):
    def countWordsInSubChapter(subchapter):
        global numberOfTimesRan
        numberOfTimesRan += 1
        accum = 0
        text = subchapter.text
        words = text.split()
        filtered_words = [w for w in words if not w.lower() in stopWords and not isInt(w)]
        print filtered_words
        for word in filtered_words:
            comp = levenshteinDistance(input_string,word)
            accum += float(comp) / len(words)
        return accum
    
    countWordsInSubChapter = memoize(countWordsInSubChapter)
    
    def chapterPlusIndex(chapter):
        index = levenshteinDistance(input_string, chapter.name)
        if type(chapter) is SubChapter:
            index += countWordsInSubChapter(chapter)
            
        elif type(chapter) is Chapter:
            accum = 0
            for subchapter in chapter.subchapters:
                accum += countWordsInSubChapter(subchapter)
            accum = accum/len(chapter.subchapters)
            index += accum
        print index
            
        return (float(index), chapter)
    xs = map(chapterPlusIndex, chapters)
#     print map(lambda x: (x[0], x[1].name), xs)
    return minimumChapter(xs)

# %%
def memoize(f):
    memory = dict()
    def memoizedFunction(x):
        if x in memory:
            return memory[x]
        else:
            memory[x] = f(x)
            return memory[x]
    return memoizedFunction

# %%
def getChapter(input_string):
    return bestChapter(input_string, book.chapters + list(chain(*[c.subchapters for c in book.chapters])))

# %%
def levenshteinDistance(str1,str2):
    str1, str2 = unicode(str1), unicode(str2)
    return levenshtein(str1.lower().rstrip('.'),str2.lower().rstrip('.'))

# %%
def isInt(string):
    string = [x for x in string if x in '0123456789']
    return len(string) > 0

# %% [markdown]
# ###### Search Data

# %%
stopwords = """
a about above after again agains all am an and any are aren't as at be because been before being below between both but by can't cannot could couldn't did didn't do does doesn't doing don't down during each few for from further had hadn't has hasn't have haven't having he he'd he'll he's her here here's hers herself him himself his how how's i i'd i'll i'm i've if in into is isn't it it's its itself let's me more most mustn't my myself no nor not of off on once only or other ought our ours ourselves out over own same shan't she she'd she'll she's should shouldn't so some such than that that's the their theirs them themselves then there there's these they they'd they'll they're they've this those through to too under until up very was wasn't we we'd we'll we're we've were weren't what what's when when's where where's which while who who's whom why why's with won't would wouldn't you you'd you'll you're you've your yours yourself yourselves first twice third fourth
"""
stopWords = stopwords.split()

# %%
input_string = u'itself'
print getChapter(input_string).name
# Out:
ars', u'gained', u'y', u'dollars.', u'sheep', u'cost?', u'Ans.', u'm', u'-', u'y', u'dollars.', u'Subtraction', u'expressed', u'sign', u'minus', u'(-).', u'ILLUS.', u'man', u'started', u'certain', u'point', u'traveled', u'north', u'miles,', u'south', u'miles,', u'north', u'miles,', u'north', u'miles,', u'south', u'miles.', u'far', u'started', u'direction?', u'ILLUS.', u'man', u'started', u'certain', u'point', u'traveled', u'east', u'x', u'miles,', u'west', u'b', u'miles,', u'east', u'm', u'miles,', u'east', u'y', u'miles,', u'west', u'z', u'miles.', u'far', u'started?', u'find', u'difficulty', u'solving', u'last', u'example,', u'know', u'just', u'large', u'x,', u'b,', u'm,', u'y,', u'z', u'reference', u'other.', u'one', u'example', u'large', u'class', u'problems', u'may', u'arise,', u'find', u'direction', u'east', u'west,', u'north', u'south;', u'space', u'behind,', u'right', u'left,', u'below;', u'time', u'past', u'future;', u'money', u'gained', u'lost;', u'everywhere', u'opposite', u'relations.', u'relation', u'oppositeness', u'must', u'expressed', u'way', u'representation', u'numbers.', u'algebra,', u'therefore,', u'numbers', u'considered', u'increasing', u'zero', u'opposite', u'directions.', u'one', u'direction', u'called', u'Positive', u'Numbers', u'(or', u'+', u'numbers);', u'direction', u'Negative', u'Numbers', u'(or', u'-', u'numbers).', u'Illus.', u'call', u'direction', u'east', u'positive,', u'direction', u'west', u'will', u'nega-', u'tive,', u'respective', u'distances', u'man', u'traveled', u'will', u'+x,', u'-b,', u'+m,', u'+y,', u'-z.', u'Combining', u'these,', u'answer', u'problem', u'becomes', u'x', u'-', u'b', u'+', u'm', u'+', u'y', u'-', u'z.', u'analysis', u'applied', ...
# [u'-c,', u'b', u'+', u'm', u'-', u'x', u'+', u'algebraic', u'expression', u'representation', u'number', u'algebraic', u'notation.', u'+', u'-', u'called', u'term,', u'term,', u'term,', u'term.', u'term', u'algebraic', u'expression', u'connected', u'sign', u'plus', u'minus,', u'one', u'parts', u'algebraic', u'expression', u'sign', u'plus', u'minus.', u'sign', u'written,', u'plus', u'sign', u'understood.', u'signs', u'terms', u'separated?', u'ILLUS.', u'terms', u'groups', u'said', u'similar.', u'ILLUS.', u'terms', u'groups', u'said', u'dissimilar.', u'Similar', u'terms', u'terms', u'letters', u'affected', u'exponents.', u'Dissimilar', u'terms', u'terms', u'differ', u'letters', u'exponents,', u'both.', u'may', u'similar', u'terms', u'differ?', u'degree', u'....abc', u'sixth', u'degree', u'degree', u'term', u'number', u'literal', u'factors.', u'can', u'found', u'taking', u'sum', u'exponents.', u'ILLUS.', u'terms', u'compare', u'reference', u'degree?', u'called', u'homogeneous', u'terms.', u'homogeneous', u'terms?', u'ILLUS.', u'monomial.', u'-', u'called', u'polynomials.', u'-', u'monomial', u'algebraic', u'expression', u'one', u'term.', u'polynomial', u'algebraic', u'expression', u'one', u'term.', u'polynomial', u'two', u'terms', u'called', u'binomial,', u'one', u'three', u'terms', u'called', u'trinomial.', u'degree', u'algebraic', u'expression', u'degree', u'highest', u'term.', u'degree', u'polynomials', u'above?', u'homogeneous', u'polynomial?', u'Exercise', u'Write', u'polynomial', u'five', u'terms.', u'degree', u'it?', u'Write', u'binomial', u'degree.', u'Write', u'polynomial', u'terms', u'different', u'degrees.', u'Write', u'homogeneous', u'trinomial', u'degree.', u'Write', u'two', u'similar', u'monomials', u'fifth', u'degree', u'shall', u'differ', u'much', u'possible.', u'Write', u'homogeneous', u'trinomial', u'one', u'terms', u'second', u'degree.', u'Arrange', u'according', u'descending', u'powers', u'a:', u'+', u'+', u'+', u'+', u'-', u'-', u'name?', u'degree?', u'Write', u'polynomial', u'fifth', u'degree', u'containing', u'six', u'terms.', u'Arrange', u'according', u'ascending', u'powers', u'x:', u'+', u'-', u'-', u'+', u'+', u'name?', u'degree?', u'degree', u'term?', u'=', u'b', u'=', u'c', u'=', u'd', u'=', u'x', u'=', u'O,', u'y', u'=', u'find', u'value', u'following:', u'+', u'+', u'c.', u'+', u'-', u'+', u'-', u'+', u'-', u'+', u'+', u'-', u'+', u'abc.', u'+', u'+', u'-', u'-', u'-', u'-', u'b', u'-', u'.', u'a+b', u'-', u'+', u'-', u'-', u'x', u'+', u'bx.', u'.', u'abc', u'Henry', u'bought', u'apples', u'cents', u'apiece,', u'many', u'pears', u'cents', u'apiece,', u'paying', u'whole', u'cents.', u'many', u'buy?', u"Sarah's", u'father', u'told', u'difference', u'two-thirds', u'five-', u'sixths', u'age', u'years.', u'old', u'he?']
# 7.00107504485
# [u'combining', u'numbers', u'algebra', u'must', u'always', u'borne', u'mind', u'negative', u'numbers', u'opposite', u'positive', u'numbers', u'tendency.', u'ILLUS.', u'add', u'similar', u'terms', u'like', u'signs,', u'add', u'coefficients,', u'annex', u'common', u'letters,', u'prefix', u'common', u'sign.', u'ILLUS.', u'add', u'similar', u'terms', u'unlike', u'signs,', u'add', u'coefficients', u'plus', u'terms,', u'add', u'coefficients', u'minus', u'terms,', u'difference', u'sums', u'annex', u'common', u'letters,', u'prefix', u'sign', u'greater', u'sum.', u'ILLUS.', u'+', u'b', u'+', u'-', u'-', u'add', u'dissimilar', u'terms,', u'write', u'terms', u'successively,', u'sign.', u'ILLUS.', u'add', u'polynomials,', u'add', u'terms', u'polynomials', u'consist,', u'unite', u'results.', u'Exercise', u'Find', u'sum', u'of:', u'x,', u'ab,', u'-x,', u'bc,', u'Simplify:', u'-', u'-', u'-', u'+', u'-', u'-', u'+', u'+', u'-', u'+', u'+', u'a.', u'b', u'-', u'b', u'-', u'-', u'b', u'+', u'b', u'+', u'b.', u'lady', u'bought', u'ribbon', u'm', u'cents,', u'tape', u'd', u'cents,', u'thread', u'c', u'cents.', u'paid', u'x', u'cents', u'bill.', u'much', u'remains', u'due?', u'man', u'travels', u'miles', u'north,', u'x', u'miles', u'south,', u'miles', u'south,', u'y', u'miles', u'north.', u'far', u'starting', u'point?', u'Add:', u'+', u'+', u'+', u'+', u'c,', u'c', u'-', u'-', u'b.', u'x', u'+', u'y', u'-', u'z,', u'x', u'-', u'y', u'-', u'z,', u'y', u'-', u'x', u'+', u'z.', u'x', u'+', u'-', u'+', u'a,', u'-', u'+', u'z', u'-', u'-', u'+', u'y', u'-', u'z.', u'+', u'-', u'x', u'+', u'-', u'+', u'-', u'+', u'-', u'+', u'ca', u'-', u'bc', u'+', u'ab', u'+', u'-', u'ca,', u'-', u'ab', u'+', u'bc.', u'-', u'-', u'+', u'-', u'+', u'-', u'-', u'+', u'+', u'+', u'-', u'-', u'-', u'+', u'+', u'+', u'-', u'+', u'+', u'-', u'+', u'+', u'+', u'+', u'-', u'+', u'-', u'+', u'-', u'-', u'+', u'-', u'-', u'-', u'-', u'+', u'+', u'+', u'x', u'-', u'y', u'-', u'z', u'-', u'-', u'b,', u'x', u'+', u'y', u'+', u'z', u'+', u'+', u'b,', u'x', u'+', u'y', u'+', u'z', u'+', u'-', u'b,', u'x', u'+', u'y', u'-', u'z', u'-', u'-', u'b,', u'x', u'+', u'y', u'+', u'z', u'-', u'-', u'b.', u'+', u'+', u'-', u'abc', u'-', u'-', u'+', u'-', u'-', u'-', u'-', u'abc,', u'+', u'+', u'-', u'-', u'abc', u'-', u'regiment', u'drawn', u'm', u'ranks', u'b', u'men', u'each,', u'c', u'men', u'over.', u'many', u'men', u'regiment?', u'man', u'x', u'cows', u'z', u'horses.', u'exchanging', u'cows', u'another', u'man', u'horses,', u'will', u'represent', u'number', u'each?', u'class', u'pupils', u'boys', u'girls.', u'many', u'each?', u'sum', u'two', u'numbers', u'equal', u'numerically', u'opposite', u'sign?', u'sum', u'positive', u'negative', u'number', u'compare', u'value', u'positive', u'number?', u'negative', u'number?', u'sum', u'two', u'negative', u'numbers', u'compare', u'numbers?', u'Illustrate', u'questions', u'man', u'traveling', u'north', u'south.']
# [u'subtraction', u'related', u'addition?', u'opposite', u'relations', u'ex-', u'pressed?', u'Given', u'typical', u'series', u'numbers', u'-a,', u'a,', u'must', u'added', u'obtain', u'must', u'subtracted', u'obtain', u'-', u'=?', u'must', u'added', u'obtain', u'must', u'subtracted', u'obtain', u'-', u'=?', u'must', u'added', u'obtain', u'must', u'subtracted', u'obtain', u'-', u'=?', u'must', u'added', u'-a', u'obtain', u'must', u'subtracted', u'obtain', u'-a?', u'-', u'=?', u'Examine', u'now', u'results', u'expressed', u'another', u'form.', u'-a-a', u'principle', u'clear;', u'namely,', u'subtraction', u'number', u'gives', u'result', u'addi-', u'tion', u'number', u'opposite', u'sign.', u'ILLUS.', u'+', u'-', u'c', u'+', u'b', u'-', u'+', u'+', u'subtract', u'one', u'number', u'another,', u'consider', u'sign', u'subtrahend', u'changed', u'add.', u'relation', u'minuend', u'subtrahend', u'remainder?', u'relation', u'subtrahend', u'minuend', u'remainder?', u'Exercise', u'take', u'take', u'Subtract', u'take', u'Subtract', u'take', u'difference', u'difference', u'take', u'sum', u'+', u'b', u'+', u'take', u'+', u'-', u'-', u'+', u'take', u'-', u'+', u'z.', u'Subtract', u'-', u'+', u'-', u'-', u'-', u'+', u'+', u'take', u'+', u'-', u'Subtract', u'-', u'x', u'+', u'-', u'-', u'+', u'-', u'x.', u'xm', u'-', u'+', u'take', u'-', u'-', u'xm.', u'Subtract', u'+', u'anxn', u'+', u'-', u'-', u'-', u'-', u'take', u'-', u'+', u'-', u'.', u'+', u'take', u'+', u'+', u'-', u'+', u'x', u'take', u'y', u'-', u'a.', u'+', u'+', u'take', u'sum', u'+', u'+', u'-', u'+', u'-', u'Subtract', u'sum', u'must', u'subtracted', u'+', u'+', u'-', u'-', u'leave', u'remainder', u'-', u'+', u'-', u'+', u'much', u'must', u'added', u'-', u'+', u'produce', u'+', u'must', u'-', u'+', u'-', u'added', u'produce', u'zero?', u'must', u'-', u'+', u'-', u'subtracted', u'produce', u'unity?', u'must', u'subtracted', u'sum', u'+', u'+', u'-', u'-', u'leave', u'remainder', u'-', u'-', u'difference', u'take', u'sum', u'+', u'+', u'-', u'+', u'must', u'added', u'make', u'b?', u'much', u'-', u'exceed', u'+', u'y', u'years', u'man', u'will', u'years', u'old.', u'present', u'age?', u'many', u'hours', u'will', u'take', u'go', u'miles', u'miles', u'hour?', u'PARENTHESES', u'.', u'+', u'b).', u'ILLUS.', u'+', u'n)(x', u'+', u'y).', u'ILLUS.', u'-', u'(a', u'+', u'y', u'-', u'c).', u'parenthesis', u'indicates', u'numbers', u'enclosed', u'considered', u'one', u'number.', u'Read', u'illustrations,', u'state', u'operations', u'expressed,', u'show', u'parenthesis', u'indicates.', u'Write', u'expressions', u'following:', u'sum', u'b,', u'multiplied', u'minus', u'b.', u'c', u'plus', u'd,', u'times', u'sum', u'b,--the', u'whole', u'multiplied', u'x', u'minus', u'y.', u'sum', u'b,', u'minus', u'difference', u'two', u'three', u'b.', u'(x', u'-', u'y)', u'+', u'(x', u'-', u'y)', u'+', u'(x', u'-', u'y)+', u'etc.,', u'written', u'times.', u'sum', u'+', u'b', u'taken', u'seven', u'times.', u'library', u'm', u'+', u'n', u'books,', u'book', u'c', u'-', u'd', u'pages,', u'page', u'contains', u'x', u'+', u'y', u'words.', u'many', u'words', u'books?', u'ILLUS.', u'+', u'(b', u'-', u'c', u'-', u'x)', u'=', u'+', u'b', u'-', u'c', u'-', u'x.', u'(By', u'performing', u'addition.)', u'ILLUS.', u'+', u'c', u'-', u'd', u'+', u'e', u'=', u'+', u'(c', u'-', u'd', u'+', u'e).', u'number', u'terms', u'may', u'removed', u'parenthesis', u'preceded', u'plus', u'sign', u'without', u'change', u'terms.', u'conversely,', u'number', u'terms', u'may', u'enclosed', u'parenthesis', u'preceded', u'plus', u'sign', u'without', u'change', u'terms.', u'ILLUS.', u'-', u'(y', u'+', u'z', u'-', u'c)', u'=', u'x', u'-', u'y', u'-', u'z', u'+', u'c.', u'(By', u'performing', u'subtraction.)', u'ILLUS.', u'-', u'b', u'-', u'c', u'+', u'd', u'=', u'-', u'(b', u'+', u'c', u'-', u'd).', u'number', u'terms', u'may', u'removed', u'parenthesis', u'preceded', u'minus', u'sign', u'changing', u'sign', u'term.', u'conversely,', u'number', u'terms' ...
', u'z.', u'+', u'+', u'+', u'+', u'+', u'+', u'x', u'-', u'y.', u'-', u'+', u'+', u'+', u'-', u'+', u'+', u'+', u'+', u'+', u'+', u'+', u'+', u'-', u'-', u'+', u'-', u'+', u'+', u'-', u'x', u'represent', u'number', u'miles', u'man', u'can', u'row', u'hour', u'still', u'water,', u'far', u'can', u'man', u'row', u'hours', u'stream', u'flows', u'y', u'miles', u'hour?', u'far', u'stream', u'hours?', u'can', u'reap', u'field', u'hours,', u'B', u'can', u'reap', u'field', u'hours.', u'much', u'field', u'can', u'one', u'hour,', u'working', u'together?', u'tank', u'can', u'filled', u'two', u'pipes', u'hours', u'b', u'hours', u'respectively.', u'part', u'tank', u'will', u'filled', u'pipes', u'running', u'together', u'one', u'hour?', u'x', u'-', u'y', u'express?', u'two', u'operations', u'will', u'give', u'result?', u'operations', u'will', u'give', u'result?', u'ILLUS.', u'x', u'+', u'x', u'+', u'+', u'+', u'+', u'+', u'ILLUS.', u'x', u'-', u'x', u'-', u'-', u'-', u'+', u'-', u'+', u'ILLUS.', u'x', u'+', u'x', u'- ...
# [u'relation', u'division', u'multiplication?', u'\xd7', u'=?', u'\xf7', u'=?', u'Division', u'process', u'which,', u'product', u'given', u'one', u'factor', u'known,', u'factor', u'found.', u'relation', u'dividend', u'divisor', u'quotient?', u'factors', u'must', u'dividend', u'contain?', u'factors', u'must', u'quotient', u'contain?', u'ILLUS.', u'\xf7', u'=', u'ILLUS.', u'relation', u'dividend,', u'divisor,', u'quotient,', u'law', u'signs', u'multiplication,', u'obtain', u'quotients', u'Illus.', u'divide', u'monomial', u'monomial,', u'divide', u'coefficient', u'dividend', u'coefficient', u'divisor', u'coefficient', u'quotient,', u'subtract', u'exponent', u'letter', u'divisor', u'exponent', u'letter', u'dividend', u'exponent', u'letter', u'quotient:', u'dividend', u'divisor', u'like', u'signs,', u'give', u'quotient', u'plus', u'sign;', u'unlike,', u'minus', u'sign.', u'Exercise', u'Divide:', u'-', u'-', u'-', u'-', u'-', u'+', u'+', u'-', u'-', u'b)x.', u'Simplify', u'\xd7', u'\xf7', u'Simplify', u'\xd7', u'\xf7', u'Expand', u'-', u'man', u'can', u'ride', u'one', u'mile', u'cents,', u'far', u'can', u'two', u'men', u'ride', u'b', u'cents?', u'many', u'days', u'can', u'x', u'men', u'earn', u'much', u'men', u'y', u'days?', u'times', u'b', u'many', u'times', u'c?', u'ILLUS.', u'divide', u'polynomial', u'monomial,', u'divide', u'term', u'dividend', u'divisor,', u'add', u'quotients.', u'Exercise', u'Divide:', u'-', u'+', u'+', u'-', u'-', u'-', u'-', u'+', u'+', u'-', u'-', u'-', u'+', u'-', u'-', u'+', u'-', u'-', u'+', u'-', u'-', u'abx', u'-', u'acx', u'ax.', u'-', u'+', u'xy', u'+', u'x', u'-', u'x.', u'army', u'drawn', u'x', u'men', u'front', u'y', u'men', u'deep.', u'many', u'men', u'army?', u'many', u'minutes', u'will', u'train', u'go', u'x', u'miles', u'rate', u'miles', u'hour?', u'many', u'apples', u'x', u'cents', u'apiece', u'can', u'bought', u'b', u'dollars?', u'Since', u'division', u'reverse', u'multiplication,', u'let', u'us', u'consider', u'example', u'multiplication', u'polynomials.', u'+', u'+', u'-', u'+', u'+', u'+', u'-', u'-', u'-', u'+', u'+', u'+', u'+', u'numbers', u'will', u'become', u'dividend', u'division?', u'Take', u'+', u'divisor.', u'will', u'quotient?', u'Write', u'names', u'opposite', u'different', u'numbers.', u'last', u'operation', u'performed', u'obtaining', u'dividend?', u'dividend?', u'partial', u'products', u'obtained?', u'Keeping', u'facts', u'mind,', u'will', u'start', u'work', u'division,', u'using', u'numbers', u'convenience.', u'ILLUS.', u'+', u'+', u'+', u'+', u'+', u'+', u'-', u'+', u'-', u'-', u'+', u'+', u'term', u'dividend', u'formed?', u'can', u'term', u'quotient', u'found?', u'Knowing', u'divisor', u'term', u'quotient,', u'can', u'formed?', u'Subtract', u'dividend.', u'term', u'remainder', u'formed?', u'can', u'now', u'found?', u'How?', u'can', u'formed?', u'etc.,', u'etc.', u'long', u'can', u'process', u'continued?', u'ILLUS.', u'-', u'+', u'+', u'+', u'stop', u'work', u'point', u'given?', u'complete', u'quotient?', u'dividend', u'exactly', u'divisible', u'divisor?', u'one', u'number', u'exactly', u'divisible', u'another?', u'divide', u'polynomial', u'polynomial,', u'arrange', u'terms', u'dividend,', u'divisor', u'similarly,', u'divide', u'term', u'dividend', u'term', u'divisor', u'term', u'quotient,', u'multiply', u'divisor', u'quotient', u'subtract', u'product', u'dividend;', u'divide', u'term', u'remainder', u'term', u'divisor', u'next', u'term', u'quotient,', u'multiply', u'subtract', u'before;', u'continue', u'work', u'dividing,', u'multiplying,', u'subtracting', u'remainder', u'term', u'remainder', u'divisible', u'term', u'divisor.', u'Exercise', u'Divide:', u'+', u'-', u'x', u'+', u'+', u'-', u'x', u'+', u'+', u'-', u'-', u'-', u'-', u'+', u'-', u'+', u'+', u'-', u'well', u'teacher', u'work', u'example', u'board', u'class', u'along', u'line', u'questions', u'follow', u'example.', u'-', u'+', u'-', u'-', u'-', u'x', u'-', u'y.', u'+', u'+', u'b.', u'-', u'-', u'-', u'-', u'y.',  ...
# 7.32669572586
# [u'divide', u'number', u'two', u'numbers,', u'multiplied', u'together', u'will', u'give', u'product', u'equal', u'given', u'number,', u'found', u'factors', u'number.', u'process', u'called', u'factoring.', u'Name', u'two', u'factors', u'Name', u'three', u'factors', u'CASE', u'I.', u'factor', u'polynomial', u'factor', u'common', u'terms.', u'ILLUS.Factor', u'+', u'+', u'+', u'+', u'b', u'+', u'+', u'+', u'+', u'=', u'(b', u'+', u'+', u'Divide', u'polynomial', u'largest', u'factor', u'common', u'terms.', u'quo-', u'tient', u'divisor', u'factors', u'polynomial.', u'Exercise', u'Factor:', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'+', u'ab.', u'+', u'+', u'-', u'+', u'-', u'+', u'x.', u'-', u'+', u'+', u'y)', u'+', u'+', u'y)', u'-', u'+', u'y).', u'-', u'b)', u'-', u'-', u'b)', u'+', u'(a', u'-', u'b)', u'-', u'-', u'b).', u'-', u'-', u'-', u'+', u'-', u'-', u'+', u'-', u'-', u'+', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'-', u'lady', u'bought', u'ribbon', u'm', u'cents,', u'tape', u'd', u'cents,', u'thread', u'c', u'cents,', u'paid', u'x', u'cents', u'account.', u'much', u'remains', u'due?', u'Julia', u'number', u'beads', u'hand.', u'change', u'two', u'left', u'hand', u'right', u'hand,', u'right', u'hand', u'contain', u'many', u'left.', u'many', u'beads', u'she?', u'Sometimes', u'polynomial', u'form', u'given', u'factor', u'common', u'terms,', u'factors', u'common', u'several', u'terms.', u'may', u'possible', u'group', u'terms', u'parentheses', u'will', u'binomial', u'trinomial', u'factor', u'common', u'terms', u'polynomial', u'new', u'form.', u'ILLUS.', u'+', u'+', u'bm', u'+', u'bx.', u'+', u'+', u'bm', u'+', u'bx', u'=', u'+', u'x)', u'+', u'b(m', u'+', u'x).', u'm', u'+', u'+', u'x)+b(m', u'+', u'x)', u'+', u'+', u'bm', u'+', u'bx', u'=', u'(m', u'+', u'+', u'b).', u'ILLUS.', u'+', u'-', u'-', u'+', u'+', u'+', u'-', u'-', u'+', u'+', u'=', u'+', u'-', u'+', u'+', u'+', u'+', u'+', u'+', u'+', u'+', u'-', u'-', u'+', u'+', u'=', u'+', u'-', u'+', u'Exercise', u'Factor:', u'ax', u'+', u'ay', u'+', u'bx', u'+', u'by.', u'+', u'ax', u'+', u'bx', u'+', u'ab.', u'+', u'-', u'-', u'-', u'ax', u'+', u'-', u'ax', u'-', u'bx', u'+', u'ab', u'-', u'+', u'mxy', u'-', u'-', u'-', u'+', u'-', u'mx', u'-', u'ma', u'-', u'nx', u'+', u'na.', u'+', u'+', u'x', u'+', u'-', u'+', u'y', u'-', u'+', u'-', u'-', u'+', u'x', u'+', u'+', u'abx', u'+', u'ac', u'+', u'aby', u'+', u'+', u'bc.', u'ax', u'-', u'bx', u'+', u'+', u'cy', u'-', u'cx', u'-', u'ay.', u'+', u'-', u'-', u'-', u'+', u'cy', u'-', u'+', u'-', u'cx.', u'+', u'-', u'-', u'man', u'acres', u'land', u'houses.', u'trading', u'x', u'houses', u'y', u'acres', u'land,', u'many', u'each?', u'number', u'will', u'become', u'four', u'times', u'large', u'adding', u'it?', u'fifth', u'seventh', u'number', u'together', u'equal', u'number?', u'CASE', u'II.', u'factor', u'difference', u'squares', u'two', u'num-', u'bers.', u'ILLUS.', u'-', u'=', u'(a', u'+', u'b)(a', u'-', u'b).', u'ILLUS.', u'-', u'=', u'+', u'-', u'ILLUS.', u'-', u'=', u'+', u'-', u'=', u'+', u'+', u'-', u'=', u'+', u'+', u'+', u'y)(x', u'-', u'y).', u'Write', u'two', u'factors,', u'one', u'sum', u'difference', u'square', u'roots', u'terms.', u'Exercise', u'Factor:', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'l.', u'-', u'-', u'-', u'-', u'-', u'-', u'+', u'-', u'+', u'-', u'-', u'-', u'+', u'ay.', u'-', u'-', u'-', u'x.', u'much', u'x', u'exceed', u'Eleven', u'years', u'ago', u'C', u'three', u'times', u'old', u'D', u'whose', u'age', u'x', u'years.', u"C's", u'present', u'age', u'?', u'CASE', u'III.', u'factor', u'sum', u'cubes', u'two', u'numbers.', u'ILLUS.', u'Divide', u'+', u'+', u'b.', u'ILLUS.', u'Divide', u'+', u'm', u'+', u'ny.', u'ILLUS.', u'Divide', u'+', u'+', u'Notice', u'case', u'above:', u'divisor', u'sum', u'cube', u'roots', u'terms', u'dividend.', u'quotient', u'square', u'term', u'divisor,', u'minus', u'product', u'term', u'second,', u'plus', u'square', u's ...
# [u'factors', u'factors', u'them?', u'largest', u'number', u'factor', u'them?', u'number', u'called', u'Greatest', u'Common', u'Factor.', u'factors', u'numbers', u'contain?', u'ILLUS.', u'Find', u'G.C.F.', u'+', u'+', u'+', u'+', u'=', u'+', u'b)', u'+', u'+', u'=', u'+', u'b)(a', u'+', u'b)', u'G.C.F.', u'=', u'find', u'G.C.F.', u'two', u'numbers,', u'find', u'prime', u'factors', u'numbers', u'take', u'product', u'common', u'factors.', u'Exercise', u'Find', u'G.C.F.', u'following:', u'+', u'+', u'-', u'-', u'+', u'-', u'-', u'-', u'mx', u'-', u'ma', u'-', u'nx', u'+', u'na', u'-', u'-', u'-', u'+', u'-', u'-', u'x,', u'-', u'+', u'-', u'+', u'x', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'-', u'y,', u'+', u'-', u'-', u'y.', u'-', u'xy', u'-', u'+', u'xz', u'-', u'yz,', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'-', u'+', u'-', u'merchant', u'mixes', u'pounds', u'tea', u'worth', u'x', u'cents', u'pound', u'b', u'pounds', u'worth', u'y', u'cents', u'pound.', u'much', u'mixture', u'worth', u'per', u'pound?', u'man', u'bought', u'horse', u'x', u'dollars', u'sold', u'gain', u'will', u'represent', u'number', u'dollars', u'gained?', u'difference', u'two', u'numbers', u'added', u'greater,', u'result', u'will', u'three', u'times', u'smaller.', u'numbers?', u'many', u'terms', u'expression', u'-', u'+', u'consist?', u'many', u'factors', u'terms?', u'value', u'number,', u'one', u'whose', u'factors', u'zero?']
# [u'ILLUS.', u'least', u'common', u'multiple', u'many', u'factors', u'found', u'L.C.M.?', u'many', u'factors', u'ILLUS.', u'Find', u'L.C.M.', u'+', u'-', u'-', u'+', u'+', u'b)', u'-', u'+', u'b)(a', u'-', u'b)', u'-', u'-', u'b)', u'+', u'b)(a', u'-', u'b)', u'find', u'L.C.M.', u'two', u'numbers,', u'find', u'prime', u'factors', u'number,', u'take', u'product', u'different', u'factors,', u'using', u'greatest', u'number', u'times', u'found', u'numbers.', u'Exercise', u'.', u'Find', u'L.C.M.', u'following:', u'-', u'+', u'-', u'+', u'+', u'+', u'-', u'-', u'-', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'-', u'+', u'+', u'+', u'-', u'-', u'+', u'm.', u'-', u'+', u'-', u'-', u'-', u'-', u'+', u'+', u'+', u'-', u'-', u'+', u'xy', u'-', u'-', u'y', u'+', u'-', u'-', u'-', u'-', u'-', u'-', u'x', u'-', u'+', u'+', u'+', u'-', u'+', u'x.', u'+', u'+', u'-', u'+', u'-', u'-', u'-', u'+', u'+', u'-', u'-', u'-', u'-', u'+', u'-', u'-', u'-', u'-', u'-', u'-', u'x,', u'-', u'+', u'-', u'abx', u'-', u'ab.', u'thermometer', u'now', u'indicates', u'c', u'degrees', u'zero
# [u'ILLUS.', u'Reduce', u'lowest', u'terms.', u'\xf7', u'=', u'\xf7', u'ILLUS.', u'Reduce', u'lowest', u'terms.', u'-', u'-', u'\xf7', u'bx(a', u'-', u'b)a', u'+', u'b', u'==', u'-', u'-', u'b)', u'\xf7', u'bx(a', u'-', u'b)a', u'reduce', u'fraction', u'lowest', u'terms,', u'divide', u'terms', u'fraction', u'greatest', u'common', u'factor.', u'Exercise', u'Reduce', u'lowest', u'terms:', u'.', u'.', u'-', u'+', u'+', u'x', u'-', u'+', u'+', u'-', u'-', u'+', u'-', u'-', u'-', u'mx', u'-', u'ny', u'+', u'nx', u'-', u'ax', u'-', u'+', u'-', u'ay', u'ac', u'-', u'bd', u'+', u'ad', u'-', u'bc', u'ax', u'-', u'+', u'-', u'bx', u'-', u'+', u'-', u'-', u'-', u'+', u'+', u'+', u'-', u'+', u'-', u'+', u'-', u'+', u'+', u'-', u'-', u'-', u'-', u'+', u'+', u'+', u'+', u'-', u'(a', u'-', u'two-thirds', u'cent', u'apiece,', u'b', u'apples', u'cost?', u'James', u'x', u'times', u'old', u'George.', u'James', u'years', u'old,', u'old', u'George?', u'ac-bc-d', u'ILLUS.', u'Change', u'equivalent', u'entire', u'mixed', u'number.', u'c', u'ac', u'-', u'bc', u'-', u'dd', u'=', u'-', u'b', u'-', u'cc', u'find', u'entire', u'mixed', u'number', u'equivalent', u'given', u'fraction,', u'divide', u'numerator', u'denominator.', u'aa-x', u'ILLUS.', u'Change', u'equivalent', u'fractions', u'b', u'+', u',', u'b', u'-', u'.', u'c', u'c', u'abc', u'+', u'aa', u'-', u'xbc', u'-', u'+', u'x', u'b', u'+=,b', u'-=', u'cccc', u'find', u'fraction', u'equivalent', u'given', u'mixed', u'number,', u'multiply', u'entire', u'part', u'denominator', u'fraction,', u'add,', u'numerator', u'sign', u'fraction', u'plus,', u'subtract', u'sign', u'minus,', u'write', u'result', u'denominator.', u'may', u'entire', u'number', u'changed', u'fraction', u'given', u'denom-', u'inator?', u'acx', u'ILLUS.', u'Change', u',', u',', u'equivalent', u'fractions', u'common', u'b', u'd', u'ab', u'denominator.', u'\xd7', u'ad', u'=', u'b', u'\xd7', u'adabd', u'c', u'\xd7', u'ab', u'=', u'abc', u'd', u'\xd7', u'ababd', u'x', u'\xd7', u'd', u'=', u'xd', u'ab', u'\xd7', u'dabd', u'change', u'fractions', u'equivalent', u'fractions', u'common', u'denominator,', u'multiply', u'terms', u'fraction', u'number', u'will', u'make', u'denomi-', u'nator', u'equal', u'L.C.M.', u'given', u'denominators.', u'Exercise', u'Change', u'equivalent', u'entire', u'mixed', u'numbers:', u'bx', u'-', u'cx', u'+', u'm', u'x', u'mn', u'+', u'+', u'x', u'n', u'+', u'+', u'x', u'-', u'y', u'+', u'+', u'x', u'-', u'y', u'-', u'+', u'+', u'-', u'+', u'-', u'+', u'-', u'x', u'-', u'+', u'-', u'+', u'+', u'-', u'+', u'x', u'-', u'y', u'-', u'+', u'b', u'-', u'+', u'+', u'+', u'+', u'-', u'+', u'+', u'-', u'+', u'+', u'+', u'-', u'+', u'+', u'-', u'-', u'+', u'x', u'-', u'-',
# [u'bba', u'+', u'+', u'ccx', u'ILLUS.,,,', u'xx', u'b', u'dd', u'-', u'd', u'-', u'yy', u'c', u'complex', u'fraction', u'one', u'fraction', u'one', u'terms.', u'simple', u'fraction?', u'effect', u'multiplying', u'simple', u'fraction', u'denominator', u'multiple', u'denominator?', u'must', u'ax', u'+', u'b', u'numerator', u'complex', u'fractionbe', u'multiplied', u'make', u'numerator', u'cx', u'+', u'd', u'ab', u'entire', u'number?', u'multiply', u'denominator', u'make', u'entire', u'num-', u'ber?', u'numerator', u'denominator', u'multiplied,', u'conditions', u'will', u'value', u'fraction', u'remain', u'same?', u'ax', u'+', u'b', u'ILLUS.', u'Simplify.', u'cx', u'+', u'd', u'ab', u'ax', u'+', u'+', u'\xd7', u'abd', u'b', u'=', u'cx', u'+', u'\xd7', u'abd', u'abc', u'+', u'dx', u'd', u'ab', u'-', u'ILLUS.', u'Simplify.', u'+', u'-', u'\xd7', u'-', u'+', u'+', u'x', u'-', u'+', u'===', u'x', u'+', u'\xd7', u'-', u'+', u'x)', u'+', u'x', u'+', u'-', u'simplify', u'complex', u'fraction,', u'multiply', u'term', u'complex', u'fraction', u'L.C.M.', u'denominators', u'fractions', u'terms,', u'reduce.', u'Exercise', u'Simplify:', u'+', u'b', u'x', u'-', u'b', u'x', u'+', u'y', u'b', u'm', u'-', u'y', u'x', u'b', u'+', u'c', u'x', u'-', u'-', u'x', u'ab', u'-', u'b', u'-', u'b', u'+', u'+', u'm', u'xz', u'-', u'y', u'x', u'ab', u'-', u'y', u'x', u'ab', u'-', u'c', u'ab', u'-', u'd', u'+', u'-', u'.', u'+', u'x', u'-', u'-', u'x', u'-', u'+', u'aa', u'+', u'a+b', u'a-b', u'+', u'-', u'a-b', u'-.', u'+', u'-', u'ba+b', u'+', u'a+b', u'b', u'many', u'pounds', u'pepper', u'can', u'bought', u'y', u'dollars,', u'x', u'pounds', u'cost', u'dimes?', u'many', u'inches', u'y', u'feet?', u'many', u'yards?', u'man', u'bought', u'x', u'pounds', u'beef', u'x', u'cents', u'pound,', u'handed', u'butcher', u'y-dollar', u'bill.', u'many', u'cents', u'change', u'receive?', u'x', u'times', u'many', u'times', u'm?', u'Exercise', u'(Review.)', u'Divide', u'-', u'+', u'+', u'+', u'+', u'-', u'-', u'+', u'-', u'+', u'Find', u'two', u'numbers', u'whose', u'sum', u'whose', u'difference', u'Find', u'G.C.F.', u'-', u'+', u'-', u'-', u'+', u'x', u'+', u'-', u'x', u'-', u'Factor', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'Reduceto', u'lowest', u'terms.', u'+', u'+', u'-', u'b)', u'Factor-.', u'x', u'y', u'stand', u'digits', u'number', u'two', u'places,', u'will', u'represent', u'number?', u'Find', u'L.C.M.', u'-', u'+', u'-', u'-', u'-', u'+', u'-', u'one', u'picture', u'costs', u'cents,', u'many', u'can', u'bought', u'x', u'dollars?', u'Simplify:', u'x', u'-', u'-', u'x)x', u'-', u'x', u'-', u'-', u'+', u'-', u'-', u'-', u'x)(x', u'-', u'-', u'-', u'-', u'+', u'-', u'+', u'-', u'-', u'x', u'-', u'-', u'+', u'ba', u'-', u'b', u'+', u'b)', u'--.', u'mnmn', u'x', u'+', u'x', u'-\xf7.', u'+', u'+', u'+', u'-', u'+', u'+', u'b', u'-', u'b', u'+', u'+', u'b', u'b', u'Prove', u'+', u'b)(a', u'+', u'c)(b', u'+', u'c)', u'=', u'(a', u'+', u'b', u'+', u'-', u'+', u'+', u'many', u'sevenths', u'Divide', u'-+', u'-', u'-', u'x', u'+', u'x.']
# 7.49337584201
# [u'+', u'=', u'+', u'ILLUS.', u'equation', u'expression', u'equality', u'two', u'numbers.', u'parts', u'expression', u'separated', u'sign', u'equality', u'called', u'members', u'equation.', u'last', u'letters', u'alphabet', u'used', u'represent', u'unknown', u'numbers,', u'known', u'numbers', u'represented', u'figures', u'letters', u'alphabet.', u'+', u'=', u'=', u'ILLUS.', u'-', u'=', u'=', u'x', u'ILLUS.', u'x', u'=', u'ILLUS.', u'=', u'x', u'=', u'changes', u'may', u'made', u'equation', u'destroy', u'equality', u'members.', u'Name', u'ways', u'changes', u'may', u'made.', u'+', u'b', u'=', u'a.', u'Subtracting', u'b', u'member,', u'x', u'=', u'-', u'b.', u'ILLUS.', u'-', u'b', u'=', u'c.', u'Adding', u'b', u'member,', u'x', u'=', u'c', u'+', u'b.', u'illustrations', u'b', u'transposed', u'(changed', u'over)', u'second', u'member,', u'case', u'sign', u'changed.', u'Hence,', u'term', u'may', u'transposed', u'one', u'member', u'equation', u'provided', u'sign', u'changed.', u'ab', u'+', u'-', u'xx', u'-', u'bab', u'-', u'x', u'ILLUS.-=-.', u'Multiply', u'members', u'+', u'-', u'+', u'bx', u'=', u'-', u'-', u'+', u'clear', u'equation', u'fractions,', u'multiply', u'member', u'equation', u'L.C.M.', u'denominators', u'fractional', u'terms.', u'ILLUS.', u'Solve', u'x', u'+', u'+', u'-', u'=', u'+', u'-', u'-', u'x', u'+', u'+', u'-', u'=', u'+', u'-', u'-', u'Transposing,', u'x', u'+', u'-', u'+', u'=', u'+', u'-', u'+', u'=', u'x', u'=', u'+', u'-', u'-', u'ILLUS.', u'Solve-+=-.', u'Multiply', u'+', u'-', u'-', u'+', u'=', u'-', u'-', u'+', u'-', u'+', u'+', u'=', u'-', u'+', u'Transposing,', u'+', u'+', u'-', u'=', u'-', u'-', u'+', u'=', u'x', u'=', u'solve', u'equation,', u'clear', u'fractions', u'necessary,', u'transpose', u'terms', u'containing', u'unknown', u'number', u'one', u'member', u'known', u'terms', u'other,', u'unite', u'terms,', u'divide', u'members', u'coefficient', u'unknown', u'number.', u'Exercise', u'Solve:', u'-', u'=', u'-', u'-', u'=', u'+', u'-', u'=', u'-', u'-', u'=', u'+', u'-', u'=', u'-', u'-', u'=', u'-', u'-', u'-', u'=', u'+', u'+', u'x).', u'-', u'-', u'-', u'=', u'-', u'+', u'=', u'+', u'-', u'=', u'-', u'+', u'-', u'-', u'+', u'=', u'-', u'-', u'-', u'+', u'+', u'=', u'-', u'-', u'x)', u'-', u'=', u'-', u'-', u'-', u'-', u'+', u'(x', u'-', u'-', u'=', u'(x', u'+', u'-', u'=', u'(x', u'+', u'-', u'(x', u'+', u'+', u'=', u'(x', u'+', u'+', u'(x', u'-', u'+', u'-', u'=', u'x(x', u'-', u'+', u'(x', u'-', u'+', u'-', u'(x', u'-', u'-', u'-', u'-', u'=', u'(x', u'+', u'-', u'(x', u'-', u'=', u'+', u'+', u'+', u'-', u'=', u'+', u'+', u'(x', u'+', u'+', u'(x', u'-', u'=', u'+', u'-', u'+', u'-', u'=', u'-', u'-', u'Divide', u'number', u'three', u'parts,', u'second', u'shall', u'first,', u'three', u'times', u'second.', u'man', u'certain', u'amount', u'money;', u'earned', u'four', u'times', u'much', u'next', u'week,', u'found', u'seven', u'times', u'much', u'first,', u'much', u'first?', u'many', u'fourths', u'long', u'will', u'take', u'man', u'build', u'x', u'yards', u'wall', u'builds', u'z', u'feet', u'day?', u'x', u'+', u'-=+', u'-', u'+', u'xxx', u'x', u'-+', u'=++', u'x', u'-', u'-', u'-.', u'-', u'-', u'+', u'+', u'+', u'-', u'-', u'-', u'-', u'-', u'+.', u'+', u'=++', u'x', u'+', u'-', u'xx', u'+', u'x', u'+', u'-', u'xx', u'+', u'-', u'-(x', u'-', u'-', u'x)', u'-.', u'+', u'-', u'-', u'-', u'x)', u'=+', u'long', u'will', u'take', u'man', u'walk', u'x', u'miles', u'walks', u'miles', u'b', u'hours?', u'interest', u'm', u'dollars', u'one', u'year', u'per', u'cent?', u'two', u'numbers', u'whose', u'sum', u'whose', u'difference', u'interest', u'b', u'dollars', u'y', u'years', u'per', u'cent?', u'(c', u'+', u'a)x', u'+', u'(c', u'-', u'b)x', u'=', u'(a', u'-', u'b)x', u'+', u'(a', u'+', u'b)x', u'=', u'a.', u'+', u'a(x', u'-', u'=', u'+', u'-', u'a)', u'-', u'=', u'+', u'b)', u'-', u'cxax', u'+', u'=+.', u'ac', u'-', u'+', u'=', u'+', u'-', u'x).', u'+', u'+', u'=', u'x', u'+', u'-', u'b)', u'+', u'-', u' ...
# [u'x', u'+', u'y', u'=', u'x', u'=', u'ILLUS.in', u'equations.', u'-', u'y', u'=', u'y', u'=', u'Simultaneous', u'equations', u'equations', u'unknown', u'num-', u'bers', u'value.', u'One', u'equation', u'containing', u'one', u'unknown', u'number', u'solved.', u'must', u'many', u'simultaneous', u'equations', u'unknown', u'numbers.', u'x', u'+', u'=', u'ILLUS.', u'Solve', u'+', u'y', u'=', u'Multiply', u'equation', u'+', u'=', u'+', u'y', u'=', u'=', u'y', u'=', u'find', u'value', u'x,', u'substitute', u'value', u'y', u'second', u'equation:', u'+', u'=', u'=', u'x', u'=', u'x', u'=', u'Ans.', u'y', u'=', u'+', u'=', u'ILLUS.', u'Solve', u'-', u'=', u'Multiply', u'equation', u'second', u'equation', u'+', u'=', u'-', u'=', u'Adding,', u'x', u'=', u'Substituting,', u'+', u'=', u'=', u'y', u'=', u'.', u'Multiply', u'one', u'equations', u'number', u'one', u'unknown', u'numbers', u'shall', u'like', u'coefficients.', u'signs', u'terms', u'like', u'coefficients', u'alike,', u'subtract', u'one', u'equation', u'other;', u'unlike,', u'add', u'equations.', u'Exercise', u'Solve:', u'x', u'+', u'y', u'=', u'-', u'=', u'x', u'-', u'y', u'=', u'+', u'=', u'+', u'=', u'-', u'y', u'=', u'-', u'=', u'+', u'=', u'-', u'=', u'+', u'=', u'-', u'=', u'+', u'y', u'=', u'-', u'=', u'+', u'y', u'=', u'+', u'=', u'+', u'=', u'-', u'=', u'+', u'=', u'-', u'=', u'+', u'=', u'-', u'=', u'-', u'=', u'.', u'+', u'=', u'-', u'=', u'x', u'+', u'y', u'=', u'+', u'y', u'=', u'+', u'=', u'+', u'=', u'.', u'-', u'=', u'x', u'+', u'=', u'x', u'-', u'=', u'+', u'=', u'=', u'=', u'.', u'=', u',', u'=', u'y', u'-', u'=', u'-', u',', u'-', u'=', u'+', u'.', u'x', u'+', u'y', u'=', u'a,', u'x', u'-', u'y', u'=', u'b.', u'+', u'=', u'+', u',', u'+', u'=', u'+', u'.', u'-', u'+', u'-', u'=', u'x,', u'+', u'x', u'-', u'y', u'=', u'+', u'y.', u'added', u'numerator', u'fraction,', u'value', u';', u'added', u'denominator,', u'value', u'.', u'fraction?', u'Suggestion.', u'Letting', u'x', u'equal', u'numerator,', u'y', u'denominator,', u'form', u'two', u'equations.', u'subtracted', u'numerator', u'denominator', u'certain', u'frac-', u'tion,', u'value', u';', u'added', u'numerator', u'denominator,', u'value', u'.', u'fraction?', u'added', u'numerator', u'denominator', u'certain', u'fraction,', u'value', u';', u'subtracted', u'numerator', u'denominator,', u'value', u'.', u'fraction?', u'subtracted', u'numerator', u'certain', u'fraction,', u'added', u'denominator,', u'value', u'will', u';', u'added', u'numerator,', u'subtracted', u'denominator,', u'value', u'will', u'fraction?', u'sum', u'two', u'numbers', u'divided', u'difference', u'divided', u'numbers?', u'sum', u'two', u'numbers', u'divided', u'gives', u'quotient', u'difference', u'divided', u'gives', u'numbers?', u'Five', u'years', u'ago', u'age', u'father', u'four', u'times', u'son;', u'five', u'years', u'hence', u'age', u'father', u'will', u'times', u'son.', u'ages?', u'Seven', u'years', u'ago', u'John', u'one-half', u'old', u'Henry,', u'five', u'years', u'hence', u'will', u'three-quarters', u'old.', u'old', u'each?', u'B', u'herds', u'cows.', u'sell', u'cows,', u'B', u'buy', u'number;', u'B', u'sell', u'cows', u'A,', u'half', u'many', u'A.', u'many', u'cows', u'herd?', u'cost', u'pounds', u'tea', u'pounds', u'coffee', u'cost', u'pounds', u'tea', u'pounds', u'coffee', u'cost', u'tea', u'coffee', u'per', u'pound?', u'price', u'corn', u'oats', u'bushels', u'corn', u'bushels', u'oats', u'cost', u'bushels', u'corn', u'bushels', u'oats', u'cost', u'merchant', u'mixes', u'tea', u'cost', u'cents', u'pound', u'tea', u'cost', u'cents', u'pound.', u'cost', u'mixture', u'sells', u'mixture', u'cents', u'pound', u'gains', u'many', u'pounds', u'put', u'mixture?', u'QUADRATIC', u'EQUATIONS.', u'=', u'b,', u'-', u'=', u'+', u'ILLUS.', u'+', u'=', u'+', u'bx', u'-', u'c', u'=', u'+', u'd.', u'quadratic', u'equation', u'equation', u'which,', u'highest', u'power', u'unknown', u'number', u'square.', u'called', u'equation', u'second', u'degree.', ...
# 7.27698263628
# 8.53255109765
# 5.9
# 5.41151219512
# 7.66023688663
# 6.06623931624
# 7.50696812454
# 6.59172477917
# 5.94185068349
# 7.04390333211
# 6.2878238342
# 7.09001663894
# 9.18888888889
# 7.3974248927
# 6.61406980928
# 6.97311977716
# 8.30487222355
# 5.14909304902
# SIMULTANEOUS EQUATIONS.

# %%
numberOfTimesRan
# Out:
# 17

# %%
words = []
for chapter in book.chapters:
    for subchapter in chapter.subchapters:
        splited = subchapter.text.split()
        words += splited
print words
# Out:
# [u'1.', u'Algebra', u'is', u'so', u'much', u'like', u'arithmetic', u'that', u'all', u'that', u'you', u'know', u'about', u'addition,', u'subtraction,', u'multiplication,', u'and', u'division,', u'the', u'signs', u'that', u'you', u'have', u'been', u'using', u'and', u'the', u'ways', u'of', u'working', u'out', u'problems,', u'will', u'be', u'very', u'useful', u'to', u'you', u'in', u'this', u'study.', u'There', u'are', u'two', u'things', u'the', u'introduction', u'of', u'which', u'really', u'makes', u'all', u'the', u'difference', u'between', u'arithmetic', u'and', u'algebra.', u'One', u'of', u'these', u'is', u'the', u'use', u'of', u'letters', u'to', u'represent', u'numbers,', u'and', u'you', u'will', u'see', u'in', u'the', u'following', u'exercises', u'that', u'this', u'change', u'makes', u'the', u'solution', u'of', u'problems', u'much', u'easier.', u'Exercise', u'I.', u'Illustrative', u'Example.', u'The', u'sum', u'of', u'two', u'numbers', u'is', u'60,', u'and', u'the', u'greater', u'is', u'four', u'times', u'the', u'less.', u'What', u'are', u'the', u'numbers?', u'Solution.', u'Letx=', u'the', u'less', u'number;', u'then4x=', u'the', u'greater', u'number,', u'and4x', u'+', u'x=60,', u'or5x=60;', u'thereforex=12,', u'and4x=48.', u'The', u'numbers', u'are', u'12', u'and', u'48.', u'1.', u'The', u'greater', u'of', u'two', u'numbers', u'is', u'twice', u'the', u'less,', u'and', u'the', u'sum', u'of', u'the', u'numbers', u'is', u'129.', u'What', u'are', u'the', u'numbers?', u'2.', u'A', u'man', u'bought', u'a', u'horse', u'and', u'carriage', u'for', u'$500,', u'paying', u'three', u'times', u'as', u'much', u'for', u'the', u'carriage', u'as', u'for', u'the', u'horse.', u'How', u'much', u'did', u'each', u'cost?', u'3.', u'Two', u'brothers,', u'counting', u'their', u'money,', u'found', u'that', u'together', u'they', u'had', u'$186,', u'and', u'that', u'John', u'had', u'five', u'times', u'as', u'much', u'as', u'Charles.', u'How', u'much', u'had', u'each?', u'4.', u'Divide', u'the', u'number', u'64', u'into', u'two', u'parts', u'so', u'that', u'one', u'part', u'shall', u'be', u'seven', u'times', u'the', u'other.', u'5.', u'A', u'man', u'walked', u'24', u'miles', u'in', u'a', u'day.', u'If', u'he', u'walked', u'twice', u'as', u'far', u'in', u'the', u'forenoon', u'as', u'in', u'the', u'afternoon,', u'how', u'far', u'did', u'he', u'walk', u'in', u'the', u'afternoon?', u'7', u'6.', u'For', u'72', u'cents', u'Martha', u'bought', u'some', u'needles', u'and', u'thread,', u'paying', u'eight', u'times', u'as', u'much', u'for', u'the', u'thread', u'as', u'for', u'the', u'needles.', u'How', u'much', u'did', u'she', u'pay', u'for', u'each?', u'7.', u'In', u'a', u'school', u'there', u'are', u'672', u'pupils.', u'If', u'there', u'are', u'twice', u'as', u'many', u'boys', u'as', u'girls,', u'how', u'many', u'boys', u'are', u'there?', u'Illustrative', u'Example.', u'If', u'the', u'difference', u'between', u'two', u'numbers', u'is', u'48,', u'and', u'one', u'number', u'is', u'five', u'times', u'the', u'other,', u'what', u'are', u'the', u'numbers?', u'Solution.', u'Letx=', u'the', u'less', u'number;', u'then5x=', u'the', u'greater', u'number,', u'and5x', u'-', u'x=48,', u'or4x=48;', u'thereforex=12,', u'and5x=60.', u'The', u'numbers', u'are', u'12', u'and', u'60.', u'8.', u'Find', u'two', u'numbers', u'such', u'that', u'their', u'difference', u'is', u'250', u'and', u'one', u'is', u'eleven', u'times', u'the', u'other.', u'9.', u'James', u'gathered', u'12', u'quarts', u'of', u'nuts', u'more', u'than', u'Henry', u'gathered.', u'How', u'many', u'did', u'each', u'gather', u'if', u'James', u'gathered', u'three', u'times', u'as', u'many', u'as', u'Henry?', u'10.', u'A', u'house', u'cost', u'$2880', u'more', u'than', u'a', u'lot', u'of', u'land,', u'and', u'five', u'times', u'the', u'cost', u'of', u'the', u'lot', u'equals', u'the', u'cost', u'of', u'the', u'house.', u'What', u'was', u'the', u'cost', u'of', u'each?', u'11.', u'Mr.', u'A.', u'is', u'48', u'years', u'olde ...

# %%
text = nltk.Text(list(chain(*map(nltk.word_tokenize,words))))

# %%
text.count('x')
# Out:
# 1047

# %% [markdown]
# ###### Test

# %%
book.chapters + list(chain(*[c.subchapters for c in book.chapters]))
# Out:
# [<__main__.Chapter at 0xaef1ba8>,
#  <__main__.Chapter at 0xaef1be0>,
#  <__main__.Chapter at 0xaef1d68>,
#  <__main__.Chapter at 0xaef1e48>,
#  <__main__.Chapter at 0xaef1f60>,
#  <__main__.SubChapter at 0xaef1c50>,
#  <__main__.SubChapter at 0xaef1b70>,
#  <__main__.SubChapter at 0xaef1b38>,
#  <__main__.SubChapter at 0xaef1c18>,
#  <__main__.SubChapter at 0xaef1c88>,
#  <__main__.SubChapter at 0xaef1cc0>,
#  <__main__.SubChapter at 0xaef1cf8>,
#  <__main__.SubChapter at 0xaef1d30>,
#  <__main__.SubChapter at 0xaef1da0>,
#  <__main__.SubChapter at 0xaef1dd8>,
#  <__main__.SubChapter at 0xaef1e10>,
#  <__main__.SubChapter at 0xaef1e80>,
#  <__main__.SubChapter at 0xaef1eb8>,
#  <__main__.SubChapter at 0xaef1ef0>,
#  <__main__.SubChapter at 0xaef1f28>,
#  <__main__.SubChapter at 0xaef1f98>,
#  <__main__.SubChapter at 0xaef1fd0>]

# %%
print levenshtein("ALGEBRAIC NOTATION.".lower(), "facor".lower())
# Out:
# 3.6

# %%
stopWords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'agains',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'same',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'first',
#  'twice',
#  'third',
#  'fourth']
